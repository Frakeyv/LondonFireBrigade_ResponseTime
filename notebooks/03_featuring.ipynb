# %% [markdown]
# ## 00 - importation librairies et dataframe

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from utils import dataframe_info, racine_projet

# %%
racine_projet()
# Out:
# '/Users/kfranceschi/GitHub/mai24_bds_pompiers'

# %%
df = pd.read_csv(racine_projet()+'/data/raw/merged_data.csv', low_memory = False)

# %% [markdown]
# ## 01 - data cleaning pre-viz

# %% [markdown]
# #### Création de la Target : ResponseDuration

# %%
df['DateAndTimeArrived'] = pd.to_datetime(df['DateAndTimeArrived'])
df['DateAndTimeMobilised'] = pd.to_datetime(df['DateAndTimeMobilised'])

df['ResponseDuration'] = df['DateAndTimeArrived'] - df['DateAndTimeMobilised']
df['ResponseDuration'] = df['ResponseDuration'].abs().dt.total_seconds().astype(int)

# %% [markdown]
# #### Création de la colonne DateAndTimeCalled pour supprimer les colonnes :
# DateOfCall / CalYear / TimeOfCall / HourOfCall

# %%
df['DateAndTimeCalled']= df['DateOfCall']+ [' '] + df['TimeOfCall']

# %% [markdown]
# #### Création de la colonne IncidentType

# %%
# Créer la nouvelle variable 'IncidentType'
df['IncidentType'] = df['StopCodeDescription']

# Remplacer les valeurs 'special Service' par le contenu de 'SpecialCodeDescription'
df.loc[df['StopCodeDescription'] == 'Special Service', 'IncidentType'] = df['SpecialServiceType']

# %% [markdown]
# #### Suppression de variables

# %%
#Suppresion pour cause d'inutilité / variables administratives
variables_drop0 =['IncidentNumber',
                  'ResourceMobilisationId',
                  'Resource_Code',
                  'FRS']
df_dropped = df.drop(labels = variables_drop0, axis = 1)

# %%
#Suppresion pour cause de doublon/ redondance par codification
variables_drop1 =['ProperCase',
                  'DeployedFromStation_Code',
                  'PlusCode_Code',
                  'DelayCodeId',
                  'ProperCase',
                  'PerformanceReporting',
                  'IncGeo_WardCode',
                  'IncGeo_BoroughCode']
df_dropped = df_dropped.drop(labels = variables_drop1, axis = 1)

# %%
# Suppression pour cause de %NAN trop élevé
variables_drop2 =['DelayCode_Description',
                  'DateAndTimeReturned',
                  'Postcode_full',
                  'Easting_m',
                  'Northing_m',
                  'Latitude',
                  'Longitude']
df_dropped = df_dropped.drop(labels = variables_drop2, axis = 1)

# %%
#Suppresion pour cause de colinéarité (valeurs identique par le calcul)
variables_drop3 =['DateOfCall',
                  'TimeOfCall',
                  'TurnoutTimeSeconds',
                  'TravelTimeSeconds',
                  'CalYear',
                  'HourOfCall']
df_dropped = df_dropped.drop(labels = variables_drop3, axis = 1)

# %%
df = df_dropped.copy()

# %% [markdown]
# ## 02 - ajout des data météo

# %%
weather = pd.read_csv(racine_projet()+'/data/external/weather.csv', low_memory = False)

# %%
dataframe_info(weather)
# Out:
#                  Column  Non-Null Count  NaN Count  NaN Percentage    Dtype  \
# 0                  date          135096          0             0.0   object
# 1        temperature_2m          135096          0             0.0  float64
# 2  relative_humidity_2m          135096          0             0.0  float64
# 3                  rain          135096          0             0.0  float64
# 4          weather_code          135096          0             0.0  float64
# 5        wind_speed_10m          135096          0             0.0  float64
# 6        wind_gusts_10m          135096          0             0.0  float64
#
#                Example Value
# 0  2009-01-01 00:00:00+00:00
# 1                       -0.3
# 2                   96.07175
# 3                        0.0
# 4                        2.0
# 5                   6.489992
# 6                  12.959999

# %%
df['DateAndTimeMobilised'] = pd.to_datetime(df['DateAndTimeMobilised'])
weather['date'] = pd.to_datetime(weather['date'])

# Troncature des colonnes datetime à l'heure
df['datetime_hour'] = df['DateAndTimeMobilised'].dt.floor('H')
weather['datetime_hour'] = weather['date'].dt.floor('H')

# S'assurer que les colonnes datetime_hour sont en UTC
df['datetime_hour'] = df['datetime_hour'].dt.tz_localize(None)  # Localize to None if not already UTC
weather['datetime_hour'] = weather['datetime_hour'].dt.tz_localize(None)

# Fusion des deux DataFrames en utilisant un left join
merged_df = pd.merge(df, weather, on='datetime_hour', how='left', suffixes=('_df1', '_df2'))

# Suppression des colonnes datetime_hour après la fusion
merged_df.drop(columns=['datetime_hour'], inplace=True)
# Out:
# /var/folders/rg/8x31xcvn0hddrq5cpz770vhc0000gn/T/ipykernel_63520/3928628811.py:5: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   df['datetime_hour'] = df['DateAndTimeMobilised'].dt.floor('H')
# /var/folders/rg/8x31xcvn0hddrq5cpz770vhc0000gn/T/ipykernel_63520/3928628811.py:6: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   weather['datetime_hour'] = weather['date'].dt.floor('H')

# %%
dataframe_info(merged_df)
# Out:
#                                     Column  Non-Null Count  NaN Count  \
# 0                     DateAndTimeMobilised         2365940          0
# 1                        DateAndTimeMobile         2338168      27772
# 2                       DateAndTimeArrived         2365940          0
# 3                    AttendanceTimeSeconds         2365940          0
# 4                          DateAndTimeLeft         2319613      46327
# 5                 DeployedFromStation_Name         2365917         23
# 6                     DeployedFromLocation         2364778       1162
# 7                                PumpOrder         2365940          0
# 8                     PlusCode_Description         2365940          0
# 9                            IncidentGroup         2365940          0
# 10                     StopCodeDescription         2365940          0
# 11                      SpecialServiceType          515364    1850576
# 12                        PropertyCategory         2365940          0
# 13                            PropertyType         2365940          0
# 14                        AddressQualifier         2365940          0
# 15                       Postcode_district         2365940          0
# 16                                    UPRN         2205050     160890
# 17                                    USRN         2176263     189677
# 18                      IncGeo_BoroughName         2365940          0
# 19                         IncGeo_WardName         2365493        447
# 20                      IncGeo_WardNameNew         2365493        447
# 21                         Easting_rounded         2365940          0
# 22                        Northing_rounded         2365940          0
# 23                   IncidentStationGround         2365938          2
# 24        FirstPumpArriving_AttendanceTime         2365934          6
# 25   FirstPumpArriving_DeployedFromStation         2365913         27
# 26       SecondPumpArriving_AttendanceTime         1405165     960775
# 27  SecondPumpArriving_DeployedFromStation         1405148     960792
# 28           NumStationsWithPumpsAttending         2365940          0
# 29                       NumPumpsAttending         2365940          0
# 30                               PumpCount         2365940          0
# 31                      PumpMinutesRounded         2365940          0
# 32                       Notional Cost (£)         2365940          0
# 33                                NumCalls         2364573       1367
# 34                        ResponseDuration         2365940          0
# 35                       DateAndTimeCalled         2365940          0
# 36                            IncidentType         2365940          0
# 37                                    date         2365940          0
# 38                          temperature_2m         2365940          0
# 39                    relative_humidity_2m         2365940          0
# 40                                    rain         2365940          0
# 41                            weather_code         2365940          0
# 42                          wind_speed_10m         2365940          0
# 43                          wind_gusts_10m         2365940          0
#
#     NaN Percentage                Dtype                          Example Value
# 0             0.00       datetime64[ns]                    2009-01-01 00:02:27
# 1             1.17               object                    2009-01-01 00:06:40
# 2             0.00       datetime64[ns]                    2009-01-01 00:07:46
# 3             0.00                int64                                    319
# 4             1.96               object                    2009-01-01 00:16:46
# 5             0.00               object                              Battersea
# 6             0.05               object                           Home Station
# 7             0.00                int64                                      1
# 8             0.00               object                   Initial Mobilisation
# 9             0.00               object                        Special Service
# 10            0.00               object                        Special Service
# 11           78.22               object                                    RTC
# 12            0.00               object                           Road Vehicle
# 13            0.00               object                                   Car
# 14            0.00               object  In street close to gazetteer location
# 15            0.00               object                                   SW11
# 16            6.80              float64                         100021491527.0
# 17            8.02              float64                             21401491.0
# 18            0.00               object                             WANDSWORTH
# 19            0.02               object                         Battersea Park
# 20            0.02               object                         Battersea Park
# 21            0.00                int64                                 528650
# 22            0.00                int64                                 176850
# 23            0.00               object                              Battersea
# 24            0.00              float64                                  319.0
# 25            0.00               object                              Battersea
# 26           40.61              float64                                  342.0
# 27           40.61               object                                Clapham
# 28            0.00              float64                                    2.0
# 29            0.00              float64                                    2.0
# 30            0.00                int64                                      2
# 31            0.00                int64                                     60
# 32            0.00                int64                                    255
# 33            0.06              float64                                    1.0
# 34            0.00                int64                                    319
# 35            0.00               object                    2009-01-01 00:00:37
# 36            0.00               object                                    RTC
# 37            0.00  datetime64[ns, UTC]              2009-01-01 00:00:00+00:00
# 38            0.00              float64                                   -0.3
# 39            0.00              float64                               96.07175
# 40            0.00              float64                                    0.0
# 41            0.00              float64                                    2.0
# 42            0.00              float64                               6.489992
# 43            0.00              float64                              12.959999

# %%
df = merged_df

# %% [markdown]
# ## 02 bis - enregistrement dataviz (optionnel)

# %%
# Export du nouveau tableau sous format csv
df.to_csv(racine_projet()+'/data/processed/dataviz.csv', index=False)

# %% [markdown]
# ## 03 - feature Engineering (après le dataviz)

# %%
df['DateAndTimeMobilised'] = pd.to_datetime(df['DateAndTimeMobilised'])

# Créer les colonnes 'year', 'month', 'weekday' et 'hour'
df['year'] = df['DateAndTimeMobilised'].dt.year
df['month'] = df['DateAndTimeMobilised'].dt.month
df['weekday'] = df['DateAndTimeMobilised'].dt.weekday  # Monday=0, Sunday=6
df['hour'] = df['DateAndTimeMobilised'].dt.hour

# %%
#Suppresion par inadaptabilité suite à DataViz
variables_dropfeats =['IncidentStationGround',
                      'FirstPumpArriving_DeployedFromStation',
                      'SecondPumpArriving_DeployedFromStation',
                      'DateAndTimeCalled',
                      'DateAndTimeMobilised',
                      'DateAndTimeMobile',
                      'DateAndTimeArrived',
                      'DateAndTimeLeft',
                      'AttendanceTimeSeconds',
                      'FirstPumpArriving_AttendanceTime',
                      'SecondPumpArriving_AttendanceTime',
                      'Postcode_district',
                      'IncGeo_WardName',
                      'IncGeo_WardNameNew',
                      'IncGeo_BoroughName',
                      'UPRN',
                      'USRN',
                      'IncidentGroup',
                      'StopCodeDescription',
                      'SpecialServiceType',
                      'PropertyType',
                      'PumpCount',
                      'PumpMinutesRounded',
                      'Notional Cost (£)',
                      'date'
                     ]
df_feats = df.drop(labels = variables_dropfeats, axis = 1)

# %%
dataframe_info(df_feats)
# Out:
#                            Column  Non-Null Count  NaN Count  NaN Percentage  \
# 0        DeployedFromStation_Name         2365917         23            0.00
# 1            DeployedFromLocation         2364778       1162            0.05
# 2                       PumpOrder         2365940          0            0.00
# 3            PlusCode_Description         2365940          0            0.00
# 4                PropertyCategory         2365940          0            0.00
# 5                AddressQualifier         2365940          0            0.00
# 6                 Easting_rounded         2365940          0            0.00
# 7                Northing_rounded         2365940          0            0.00
# 8   NumStationsWithPumpsAttending         2365940          0            0.00
# 9               NumPumpsAttending         2365940          0            0.00
# 10                       NumCalls         2364573       1367            0.06
# 11               ResponseDuration         2365940          0            0.00
# 12                   IncidentType         2365940          0            0.00
# 13                 temperature_2m         2365940          0            0.00
# 14           relative_humidity_2m         2365940          0            0.00
# 15                           rain         2365940          0            0.00
# 16                   weather_code         2365940          0            0.00
# 17                 wind_speed_10m         2365940          0            0.00
# 18                 wind_gusts_10m         2365940          0            0.00
# 19                           year         2365940          0            0.00
# 20                          month         2365940          0            0.00
# 21                        weekday         2365940          0            0.00
# 22                           hour         2365940          0            0.00
#
#       Dtype                          Example Value
# 0    object                              Battersea
# 1    object                           Home Station
# 2     int64                                      1
# 3    object                   Initial Mobilisation
# 4    object                           Road Vehicle
# 5    object  In street close to gazetteer location
# 6     int64                                 528650
# 7     int64                                 176850
# 8   float64                                    2.0
# 9   float64                                    2.0
# 10  float64                                    1.0
# 11    int64                                    319
# 12   object                                    RTC
# 13  float64                                   -0.3
# 14  float64                               96.07175
# 15  float64                                    0.0
# 16  float64                                    2.0
# 17  float64                               6.489992
# 18  float64                              12.959999
# 19    int32                                   2009
# 20    int32                                      1
# 21    int32                                      3
# 22    int32                                      0

# %% [markdown]
# ## 04 - traitement des NaN

# %%
df_cleaned = df_feats.copy()

# %%
# Suppression des lignes contenant des NaNs dans les features restantes : 'NumCalls', 'DeployedFromLocation','DeployedFromStation_Name'
#df_cleaned = df_cleaned.dropna(subset=['NumCalls'])
#df_cleaned = df_cleaned.dropna(subset=['DeployedFromLocation'])
#df_cleaned = df_cleaned.dropna(subset=['DeployedFromStation_Name'])
df_cleaned = df_cleaned.dropna()

# %%
dataframe_info(df_cleaned)
# Out:
#                            Column  Non-Null Count  NaN Count  NaN Percentage  \
# 0        DeployedFromStation_Name         2363411          0             0.0
# 1            DeployedFromLocation         2363411          0             0.0
# 2                       PumpOrder         2363411          0             0.0
# 3            PlusCode_Description         2363411          0             0.0
# 4                PropertyCategory         2363411          0             0.0
# 5                AddressQualifier         2363411          0             0.0
# 6                 Easting_rounded         2363411          0             0.0
# 7                Northing_rounded         2363411          0             0.0
# 8   NumStationsWithPumpsAttending         2363411          0             0.0
# 9               NumPumpsAttending         2363411          0             0.0
# 10                       NumCalls         2363411          0             0.0
# 11               ResponseDuration         2363411          0             0.0
# 12                   IncidentType         2363411          0             0.0
# 13                 temperature_2m         2363411          0             0.0
# 14           relative_humidity_2m         2363411          0             0.0
# 15                           rain         2363411          0             0.0
# 16                   weather_code         2363411          0             0.0
# 17                 wind_speed_10m         2363411          0             0.0
# 18                 wind_gusts_10m         2363411          0             0.0
# 19                           year         2363411          0             0.0
# 20                          month         2363411          0             0.0
# 21                        weekday         2363411          0             0.0
# 22                           hour         2363411          0             0.0
#
#       Dtype                          Example Value
# 0    object                              Battersea
# 1    object                           Home Station
# 2     int64                                      1
# 3    object                   Initial Mobilisation
# 4    object                           Road Vehicle
# 5    object  In street close to gazetteer location
# 6     int64                                 528650
# 7     int64                                 176850
# 8   float64                                    2.0
# 9   float64                                    2.0
# 10  float64                                    1.0
# 11    int64                                    319
# 12   object                                    RTC
# 13  float64                                   -0.3
# 14  float64                               96.07175
# 15  float64                                    0.0
# 16  float64                                    2.0
# 17  float64                               6.489992
# 18  float64                              12.959999
# 19    int32                                   2009
# 20    int32                                      1
# 21    int32                                      3
# 22    int32                                      0

# %% [markdown]
# ## 05 - cyclisation des variables cycliques (month/week/hours)

# %%
# Normalisation des variables numériques cycliques
df_norm = df_cleaned.copy()

# Utilisez .loc pour faire des assignations
df_norm['hour_sin'] = np.sin(2 * np.pi * df_norm['hour'] / 24)
df_norm['hour_cos'] = np.cos(2 * np.pi * df_norm['hour'] / 24)

df_norm['weekday_sin'] = np.sin(2 * np.pi * df_norm['weekday'] / 7)
df_norm['weekday_cos'] = np.cos(2 * np.pi * df_norm['weekday'] / 7)

df_norm.loc[:, 'month_sin'] = np.sin(2 * np.pi * df_norm['month'] / 12)
df_norm.loc[:, 'month_cos'] = np.cos(2 * np.pi * df_norm['month'] / 12)

# %%
df_norm = df_norm.drop(columns = ['month','weekday','hour'])

# %%
dataframe_info(df_norm)
dataframe_info(df_norm).to_csv(racine_projet()+'/data/processed/ML_data_info.csv', index=False)

# %% [markdown]
# ## 06 - export

# %%
# Export du nouveau tableau sous format csv
df_norm.to_csv(racine_projet()+'/data/processed/ML_data.csv', index=False)
